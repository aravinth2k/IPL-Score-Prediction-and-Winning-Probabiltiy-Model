# 17854  Narendra Modi Stadium, Ahmedabad      2            13       1     144
# 17855  Narendra Modi Stadium, Ahmedabad      3            17       1     140
# 17856  Narendra Modi Stadium, Ahmedabad      4            25       1     132
# 17857  Narendra Modi Stadium, Ahmedabad      5            37       1     120
# 17858  Narendra Modi Stadium, Ahmedabad      6            46       1     111
# 17859  Narendra Modi Stadium, Ahmedabad      7            52       1     105
# 17860  Narendra Modi Stadium, Ahmedabad      8            58       1      99
# 17861  Narendra Modi Stadium, Ahmedabad      9            69       1      88
# 17862  Narendra Modi Stadium, Ahmedabad     10            74       1      83
# 17863  Narendra Modi Stadium, Ahmedabad     11            81       2      76
# 17864  Narendra Modi Stadium, Ahmedabad     12            92       2      65
# 17865  Narendra Modi Stadium, Ahmedabad     13           107       2      50
# 17866  Narendra Modi Stadium, Ahmedabad     14           111       3      46
# 17867  Narendra Modi Stadium, Ahmedabad     15           123       3      34
# 17868  Narendra Modi Stadium, Ahmedabad     16           132       4      25
# 17869  Narendra Modi Stadium, Ahmedabad     17           139       4      18
# 17870  Narendra Modi Stadium, Ahmedabad     18           146       5      11
# 17871  Narendra Modi Stadium, Ahmedabad     19           154       7       3
# 17872  Narendra Modi Stadium, Ahmedabad      1             2       0     128
# 17873  Narendra Modi Stadium, Ahmedabad      2             7       0     123
# 17874  Narendra Modi Stadium, Ahmedabad      3            21       0     109
# 17875  Narendra Modi Stadium, Ahmedabad      4            31       1      99
# 17876  Narendra Modi Stadium, Ahmedabad      5            37       1      93
# 17877  Narendra Modi Stadium, Ahmedabad      6            44       1      86
# 17878  Narendra Modi Stadium, Ahmedabad      7            54       1      76
# 17879  Narendra Modi Stadium, Ahmedabad      8            59       1      71
# 17880  Narendra Modi Stadium, Ahmedabad      9            60       2      70
# 17881  Narendra Modi Stadium, Ahmedabad     10            71       2      59
# 17882  Narendra Modi Stadium, Ahmedabad     11            75       2      55
# 17883  Narendra Modi Stadium, Ahmedabad     12            79       3      51
# 17884  Narendra Modi Stadium, Ahmedabad     13            82       4      48
# 17885  Narendra Modi Stadium, Ahmedabad     14            84       4      46
# 17886  Narendra Modi Stadium, Ahmedabad     15            94       5      36
# 17887  Narendra Modi Stadium, Ahmedabad     16            98       6      32
# 17888  Narendra Modi Stadium, Ahmedabad     17           104       6      26
# 17889  Narendra Modi Stadium, Ahmedabad     18           120       7      10
# 17890  Narendra Modi Stadium, Ahmedabad     19           123       7       7
#
#        Overleft  Wicketleft
# 17841        12           9
# 17842        11           8
# 17843        10           8
# 17844         9           7
# 17845         8           7
# 17846         7           7
# 17847         6           6
# 17848         5           6
# 17849         4           6
# 17850         3           6
# 17851         2           6
# 17852         1           6
# 17853        19          10
# 17854        18           9
# 17855        17           9
# 17856        16           9
# 17857        15           9
# 17858        14           9
# 17859        13           9
# 17860        12           9
# 17861        11           9
# 17862        10           9
# 17863         9           8
# 17864         8           8
# 17865         7           8
# 17866         6           7
# 17867         5           7
# 17868         4           6
# 17869         3           6
# 17870         2           5
# 17871         1           3
# 17872        19          10
# 17873        18          10
# 17874        17          10
# 17875        16           9
# 17876        15           9
# 17877        14           9
# 17878        13           9
# 17879        12           9
# 17880        11           8
# 17881        10           8
# 17882         9           8
# 17883         8           7
# 17884         7           6
# 17885         6           6
# 17886         5           5
# 17887         4           4
# 17888         3           4
# 17889         2           3
# 17890         1           3

# %%
df['Overleft'] = 20 - df['Overs']
df['Wicketleft'] = 10 - df['Wicket']
df['Target'] = df['Target']-df['CurrentScore']

# %%
categorical = OneHotEncoder(sparse_output=False, drop='first')
scaler = MinMaxScaler()

# %%
X = df.drop(['Target','Overs','Wicket'],axis=1)
y = df['Target']

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X,y)

# %%
xtrain.head()
# Out:
#                  BattingTeam                  BowlingTeam  \
# 14444  Kolkata Knight Riders             Rajasthan Royals
# 12951       Rajasthan Royals  Royal Challengers Bangalore
# 289    Kolkata Knight Riders               Mumbai Indians
# 6460        Rajasthan Royals               Mumbai Indians
# 11192    Sunrisers Hyderabad                 Punjab Kings
#
#                                            Venue  CurrentScore  Overleft  \
# 14444        Dubai International Cricket Stadium            10        18
# 12951                     Sawai Mansingh Stadium           101         7
# 289                        Eden Gardens, Kolkata            40        14
# 6460                      Sawai Mansingh Stadium            72        11
# 11192  Rajiv Gandhi International Stadium, Uppal            29        14
#
#        Wicketleft
# 14444          10
# 12951           9
# 289             7
# 6460            9
# 11192           9

# %%
categorical = Pipeline(steps = [
    ('onehot', categorical)
])

categorical_cols = ['BattingTeam','BowlingTeam','Venue']
num_cols = ['CurrentScore','Overleft','Wicketleft']

preprocessor = ColumnTransformer(
    transformers= [
        ('cat', categorical, categorical_cols),
        ('num', scaler, num_cols)
    ]
)

model = LinearRegression()

# %%
master = Pipeline(
    steps=[
        ('preprocess', preprocessor),
        ('model', model)
    ]
)

# %%
master.fit(xtrain, ytrain)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    Pipeline(steps=[('onehot',
#                                                                                     OneHotEncoder(drop='first',
#                                                                                                   sparse_output=False))]))]),
#                                                   ['BattingTeam', 'BowlingTeam',
#                                                    'Venue']),
#                                                  ('num', MinMaxScaler(),
#                                                   ['CurrentScore', 'Overleft',
#                                                    'Wicketleft'])])),
#                 ('model', LinearRegression())])

# %%
ypred = master.predict(xtest)

# %%
from sklearn.metrics import root_mean_squared_error,mean_squared_error,adjusted_rand_score
print(mean_squared_error(ytest,ypred))
print(root_mean_squared_error(ytest,ypred))
adjusted_rand_score(ytest,ypred)
# Out:
# 426.6182735527747
# 20.654739735779163
# C:\Users\aravi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received multiclass values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# -4.197777132584835e-06

# %%
master.predict(pd.DataFrame({
    'BattingTeam':['Kolkata Knight Riders'],
    'BowlingTeam':['Chennai Super Kings'],
    'Venue':['MA Chidambaram Stadium, Chepauk, Chennai'],
    'Overs':[19],
    'CurrentScore':[100],	
    'Wicket':[9],
    'Overleft':[1],
    'Wicketleft':[1]
}))
# Out:
# array([-9.93899139])

# %%
xtrain.head()
# Out:
#                  BattingTeam                  BowlingTeam  \
# 14444  Kolkata Knight Riders             Rajasthan Royals
# 12951       Rajasthan Royals  Royal Challengers Bangalore
# 289    Kolkata Knight Riders               Mumbai Indians
# 6460        Rajasthan Royals               Mumbai Indians
# 11192    Sunrisers Hyderabad                 Punjab Kings
#
#                                            Venue  CurrentScore  Overleft  \
# 14444        Dubai International Cricket Stadium            10        18
# 12951                     Sawai Mansingh Stadium           101         7
# 289                        Eden Gardens, Kolkata            40        14
# 6460                      Sawai Mansingh Stadium            72        11
# 11192  Rajiv Gandhi International Stadium, Uppal            29        14
#
#        Wicketleft
# 14444          10
# 12951           9
# 289             7
# 6460            9
# 11192           9

# %%
master.predict(pd.DataFrame({
    'BattingTeam':['Kolkata Knight Riders'],
    'BowlingTeam':['Chennai Super Kings'],
    'Venue':['Punjab Cricket Association IS Bindra Stadium, Mohali'],
    'Overs':[12],
    'CurrentScore':[85],	
    'Wicket':[5],
    'Overleft':[8],
    'Wicketleft':[5]
}))
# Out:
# array([55.7126971])

# %%
import joblib

joblib.dump(master,'Lnr_Reg1.pkl')
# Out:
# ['Lnr_Reg1.pkl']
